# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# Vamos dar uma olhada nestes dados.
# Ver o que nos reservam.

# %%
#EDA

df = pd.read_csv("/Users/administrador/Documents/Codeacademy/Stack Overflow Survey Trends/developer_dataset.csv")
# Out:
# /Users/administrador/opt/anaconda3/lib/python3.9/site-packages/IPython/core/interactiveshell.py:3444: DtypeWarning: Columns (18,19,20) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)

# %%
df.describe(include="all")
# Out:
#          RespondentID           Year        Country          Employment  \
# count   111209.000000  111209.000000         111209              109425
# unique            NaN            NaN              9                   7
# top               NaN            NaN  United States  Employed full-time
# freq              NaN            NaN          53727               84707
# mean     19262.039709    2018.854832            NaN                 NaN
# std      11767.011322       0.777503            NaN                 NaN
# min          1.000000    2018.000000            NaN                 NaN
# 25%       9268.000000    2018.000000            NaN                 NaN
# 50%      18535.000000    2019.000000            NaN                 NaN
# 75%      28347.000000    2019.000000            NaN                 NaN
# max      42857.000000    2020.000000            NaN                 NaN
#
#                                            UndergradMajor  \
# ...

# %%
df.count()
# Out:
# RespondentID              111209
# Year                      111209
# Country                   111209
# Employment                109425
# UndergradMajor             98453
# DevType                   100433
# LanguageWorkedWith        102018
# LanguageDesireNextYear     96044
# DatabaseWorkedWith         85859
# DatabaseDesireNextYear     74234
# PlatformWorkedWith         91609
# PlatformDesireNextYear     85376
# Hobbyist                   68352
# OrgSize                    54804
# YearsCodePro               94793
# JobSeek                    60556
# ConvertedComp              91333
# WorkWeekHrs                51089
# NEWJobHunt                 19127
# NEWJobHuntResearch         18683
# NEWLearn                   24226
# dtype: int64

# %%
df.head()
# Out:
#    RespondentID  Year        Country          Employment  \
# 0             1  2018  United States  Employed full-time
# 1             1  2019  United States  Employed full-time
# 2             1  2020  United States  Employed full-time
# 3             2  2018  United States  Employed full-time
# 4             2  2019  United States  Employed full-time
#
#                                       UndergradMajor  \
# 0  Computer science, computer engineering, or sof...
# 1  Computer science, computer engineering, or sof...
# 2  Computer science, computer engineering, or sof...
# 3  Computer science, computer engineering, or sof...
# 4  Computer science, computer engineering, or sof...
#
#                                              DevType  \
# 0           Engineering manager;Full-stack developer
# 1                              Developer, full-stack
# 2                                                NaN
# 3                               Full-stack developer
# ...

# %% [markdown]
# Dados sobre as pessoas:
# - RespondentID
# - Year
# - Country
#
# Dados sobre experiência:
# - Employment
# - UndergradMajor
# - DevType
# - YearsCodePro
# - WorkWeekHrs
#
# Skills
# - LanguageWorkedWith
# - DatabaseWorkedWith
#
# O que desejam para o futuro:
# - LanguageDesireNextYear
# - DatabaseDesireNextYear
# - PlatformDesireNextYear
#
# O mesmo RespondentID é visto em anos diferentes. Isso sugere que o mesmo participou de pesquisas seguintes.
# Ponto e vírgula separam os diferentes itens nas rows.
#
# - Quantos RespondentID são únicos?
# - Quantos países diferentes?

# %% [markdown]
# Missing data
#
# - Qual o tipo de dado estamos lidando em cada coluna?
# - É melhor eliminar, incluir a média, utilizar dados próximos?
# - Qual o contexto de cada métrica?

# %% [markdown]
# Alguma coluna tem mais de 60% de dados nulos? Assim podemos desconsiderar estas colunas para a nossa análise.

# %%
max_rows = df["RespondentID"].count()
print("% Missing Data: ")
print(((1 - df.count() / max_rows) * 100) >= 60)
# Out:
# % Missing Data:
# RespondentID              False
# Year                      False
# Country                   False
# Employment                False
# UndergradMajor            False
# DevType                   False
# LanguageWorkedWith        False
# LanguageDesireNextYear    False
# DatabaseWorkedWith        False
# DatabaseDesireNextYear    False
# PlatformWorkedWith        False
# PlatformDesireNextYear    False
# Hobbyist                  False
# OrgSize                   False
# YearsCodePro              False
# JobSeek                   False
# ConvertedComp             False
# WorkWeekHrs               False
# NEWJobHunt                 True
# NEWJobHuntResearch         True
# NEWLearn                   True
# dtype: bool

# %%
#excluir as colunas com 60% ou mais de dados faltantes

df.drop(["NEWJobHunt", "NEWJobHuntResearch", "NEWLearn"],
axis=1,
inplace=True)

# %%
print((1 - df.count() / max_rows) * 100)
# Out:
# RespondentID               0.000000
# Year                       0.000000
# Country                    0.000000
# Employment                 1.604187
# UndergradMajor            11.470295
# DevType                    9.689863
# LanguageWorkedWith         8.264619
# LanguageDesireNextYear    13.636486
# DatabaseWorkedWith        22.794918
# DatabaseDesireNextYear    33.248208
# PlatformWorkedWith        17.624473
# PlatformDesireNextYear    23.229235
# Hobbyist                  38.537349
# OrgSize                   50.719816
# YearsCodePro              14.761395
# JobSeek                   45.547573
# ConvertedComp             17.872654
# WorkWeekHrs               54.060373
# dtype: float64

# %%
df[["RespondentID", "Country"]].groupby("Country").count()
# Out:
#                 RespondentID
# Country
# Canada                  8979
# China                   2072
# France                  6861
# Germany                16215
# Japan                   1049
# Mexico                  1918
# Spain                   4534
# United Kingdom         15854
# United States          53727

# %%
#vamos analisar duas das colunas com missing data, mas não tão significante assim (próx. de 10%)
missing_data = df[["Employment", "DevType"]].isnull().groupby(df["Country"]).sum().reset_index()

print(missing_data.head())

A = sns.catplot(data=missing_data,
kind="bar",
x="Country", y="Employment",
aspect=2,
height=6
)

B = sns.catplot(data=missing_data,
kind="bar",
x="Country", y="DevType",
aspect=2,
height=6
)
# Out:
#    Country  Employment  DevType
# 0   Canada         148      944
# 1    China         139      491
# 2   France         104      848
# 3  Germany         386     1691
# 4    Japan          13      109

# %% [markdown]
# Os dados não parecem ser tão discrepantes assim.
# MCAR = missing complete at random
# Neste caso podemos utilizar Pairwise e manter os dados das demais colunas intactas.

# %%
df.dropna(subset=["Employment", "DevType"],
inplace=True,
how="any")

# %%
df[["Employment", "DevType"]].count()
# Out:
# Employment    99975
# DevType       99975
# dtype: int64

# %%
df.describe(include='all')
# Out:
#         RespondentID          Year        Country          Employment  \
# count   99975.000000  99975.000000          99975               99975
# unique           NaN           NaN              9                   6
# top              NaN           NaN  United States  Employed full-time
# freq             NaN           NaN          48958               81176
# mean    19204.655684   2018.816194            NaN                 NaN
# std     11845.056547      0.763882            NaN                 NaN
# min         1.000000   2018.000000            NaN                 NaN
# 25%      9109.000000   2018.000000            NaN                 NaN
# 50%     18354.000000   2019.000000            NaN                 NaN
# 75%     28568.500000   2019.000000            NaN                 NaN
# max     42847.000000   2020.000000            NaN                 NaN
#
#                                            UndergradMajor  \
# count                                               90585
# ...

# %% [markdown]
# Agora podemos avaliar os dados do Employment, DevType com qualquer outro que desejarmos.
#
# Vamos analisar a distribuição do tipo de emprego em cada país

# %%
employ_fig = sns.catplot(data=df,
kind="count",
x="Country", col="Employment",
aspect=1.5,
height=6)

# %% [markdown]
# USA, UK, Germany e Canadá possuem o maior número de empregados full-time
# USA e Germany para a maioria dos part-time

# %% [markdown]
# Vamos entender a distribuição nos princiapsi roles:
# - back-end
# - front-end
# - full-stack
# - mobile
# - administrator

# %%
devdf = df[["Country", "DevType"]]
devdf.loc[devdf["DevType"].str.contains("back-end"), "BackEnd"] = True
devdf.loc[devdf["DevType"].str.contains("front-end"), "FrontEnd"] = True
devdf.loc[devdf["DevType"].str.contains("full-stack"), "FullStack"] = True
devdf.loc[devdf["DevType"].str.contains("administrator"), "Admin"] = True
devdf.loc[devdf["DevType"].str.contains("mobile"), "Mobile"] = True


devdf = devdf.melt(id_vars=["Country"],
value_vars=['BackEnd','FrontEnd','FullStack','Mobile','Admin'],
var_name="DevCat",
value_name="DevFlag")

devdf.dropna(how="any", inplace=True)

dev_fig = sns.catplot(data=devdf,
x="Country", col="DevCat",
kind="count",
height=6,
aspect=1.5)
# Out:
# /Users/administrador/opt/anaconda3/lib/python3.9/site-packages/pandas/core/indexing.py:1684: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.obj[key] = infer_fill_value(value)
# /Users/administrador/opt/anaconda3/lib/python3.9/site-packages/pandas/core/indexing.py:1817: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_column(loc, value, pi)
